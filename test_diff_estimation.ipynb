# %%
import pandas as pd
import json

# %%
# Read the .jsonl file
file_path = 'data/cls-test.jsonl'

# Load the data from jsonl
with open(file_path, 'r') as file:
    data = [json.loads(line) for line in file]

# Convert to a pandas DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#                                                    patch  y  \
# 0      @@ -87,9 +87,9 @@ public class HiveTablesTest ...  0
# 1      @@ -22,10 +22,14 @@ type LocationCache struct ...  0
# 2      @@ -0,0 +1,43 @@\n+import * as C from '../../....  1
# 3      @@ -0,0 +1,24 @@\n+// Licensed to the Software...  1
# 4      @@ -151,6 +151,27 @@ class TestCase(unittest.T...  1
# ...                                                  ... ..
# 31247  @@ -1,4 +1,4 @@\n c2.observerCardController.up...  1
# 31248  @@ -1050,7 +1050,6 @@ Lng32 ExeCliInterface::e...  0
# 31249  @@ -48,6 +48,7 @@ func (r *DefaultRuleRenderer...  0
# 31250  @@ -69,6 +69,6 @@ public final class Precondit...  1
# 31251  @@ -10005,7 +10005,7 @@ defaultdict(<class 'li...  0
#
#                                                     oldf  idx     id  \
# 0      /*\n * Copyright 2017 Netflix, Inc.\n *\n * Li...    4  13319
# 1      package manager\n\nimport (\n\t"fmt"\n\t"refle...    1  17696
# ...

# %%
df['lang'].value_counts()
# Out:
# lang
# go      9164
# java    5031
# py      4196
# cpp     3015
# js      2861
# rb      2055
# .cs     1968
# c       1777
# php     1185
# Name: count, dtype: int64

# %%
df['y'].value_counts()
# Out:
# y
# 0    15626
# 1    15626
# Name: count, dtype: int64

# %%
df_sample = df.sample(n=1000, random_state=1115)
df_sample['lang'].value_counts(0)
# Out:
# lang
# go      299
# java    149
# py      133
# js      106
# cpp     103
# rb       65
# .cs      56
# c        46
# php      43
# Name: count, dtype: int64

# %%
# Write the sampled DataFrame to a new .jsonl file
output_file_path = 'sample_output.jsonl'
with open(output_file_path, 'w') as file:
    for record in df_sample.to_dict(orient='records'):
        file.write(json.dumps(record) + '\n')

# %%
# Define the weights for sampling based on 'lang'
weights = {
    'go': 10.262,
    'java': 11.708,
    'py': 16.925,
    'cpp': 9.459,
    'js': 9.859,
    'rb': 4.706,
    '.cs': 3.442,
    'c': 4.616,
    'php': 5.665
}

weights_sum = sum(weights.values())
weights = {k: (v / weights_sum) for k, v in weights.items()}

# Map normalized weights to each row in the DataFrame
df['sampling_weight'] = df['lang'].map(weights)

# Sample 1000 rows based on normalized weights
df_sample = df.sample(n=100, weights='sampling_weight', random_state=1115)
df_sample
# Out:
#                                                    patch  y  \
# 12533  @@ -803,7 +803,7 @@ class LexicalPreservingPri...  1
# 20740  @@ -11,6 +11,8 @@ def parse_args():\n     pars...  1
# 67     @@ -850,13 +850,13 @@ define(['connectionManag...  0
# 22435  @@ -46,6 +46,7 @@ GENERIC_READ=0x80000000\n GE...  1
# 11231  @@ -269,13 +269,13 @@ static void xdg_position...  0
# ...                                                  ... ..
# 17057  @@ -5823,7 +5823,7 @@ public class ZMSImpl imp...  0
# 30587  @@ -106,4 +106,5 @@ type Filter struct {\n \tE...  0
# 5751   @@ -3462,7 +3462,7 @@ public class ZTSImpl imp...  0
# 9644   @@ -18,16 +18,30 @@ import (\n \t"time"\n \n \...  1
# 3365   @@ -517,6 +517,46 @@ func TestStopContainer(t ...  1
#
#                                                     oldf  idx     id  \
# 12533  package com.github.javaparser.printer.lexicalp...    1  13366
# 20740  import argparse\nimport os\nimport os.path as ...    1  22421
# ...

# %%
df_sample['lang'].value_counts()
# Out:
# lang
# go      33
# java    26
# py      23
# cpp      6
# js       5
# php      3
# c        2
# rb       2
# Name: count, dtype: int64

# %%
from unidiff import PatchSet

# 첫 번째 값 가져오기
patch = df_sample['patch'].iloc[1]
patch
# Out:
# "@@ -11,6 +11,8 @@ def parse_args():\n     parser.add_argument(\n         'json_path', type=str, help='json path output by benchmark_filter')\n     parser.add_argument('partition', type=str, help='slurm partition name')\n+    parser.add_argument(\n+        '--max-keep-ckpts', type=int, help='num of max keep ckpts')\n     parser.add_argument(\n         '--run', action='store_true', help='run script directly')\n     parser.add_argument("

# %%
from unidiff import PatchSet

def create_patch_set(patch):
    if not patch.startswith('---') or not patch.startswith('+++'):
        patch = f"--- a/file\n+++ b/file\n{patch}"

    # Create the PatchSet object
    patch_set = PatchSet.from_string(patch)
    return patch_set

# Example usage
patch_set = create_patch_set(patch)

# %%
# 추가된 라인과 삭제된 라인 출력
for patched_file in patch_set:
    print(f"File: {patched_file.path}")
    for hunk in patched_file:
        print(f"Hunk: {hunk}")
        for line in hunk:
            if line.is_added:
                print(f"Added: {line.value.strip()}")
            elif line.is_removed:
                print(f"Removed: {line.value.strip()}")
# Out:
# File: file
# Hunk: @@ -11,6 +11,8 @@ def parse_args():
#      parser.add_argument(
#          'json_path', type=str, help='json path output by benchmark_filter')
#      parser.add_argument('partition', type=str, help='slurm partition name')
# +    parser.add_argument(
# +        '--max-keep-ckpts', type=int, help='num of max keep ckpts')
#      parser.add_argument(
#          '--run', action='store_true', help='run script directly')
#      parser.add_argument(
# Added: parser.add_argument(
# Added: '--max-keep-ckpts', type=int, help='num of max keep ckpts')

# %%
from unidiff import PatchSet

def analyze_diff_path_set(patch_set):
    print_statements = []
    
    # Parse the hunk header to extract line numbers and changes
    for patched_file in patch_set:
        for hunk in patched_file:
            # Extract the line information from the hunk header
            old_start, old_lines = hunk.source_start, hunk.source_length
            new_start, new_lines = hunk.target_start, hunk.target_length
            print_statements.append(
                f"Changes start at line {old_start} in the original file and line {new_start} in the new file."
            )
            print_statements.append(
                f"{old_lines} lines were modified in the original file, and {new_lines} lines were modified in the new file."
            )

    # Count the number of added and removed lines
    added_lines = patch_set.added
    removed_lines = patch_set.removed

    print_statements.append(f"Total added lines: {added_lines}")
    print_statements.append(f"Total removed lines: {removed_lines}")
    
    return print_statements

# %%
print(analyze_diff_path_set(patch_set))
# Out:
# ['Changes start at line 11 in the original file and line 11 in the new file.', '6 lines were modified in the original file, and 8 lines were modified in the new file.', 'Total added lines: 2', 'Total removed lines: 0']

# %%
# Out:
# Changes start at line 850 in the original file and line 850 in the new file.
# 13 lines were modified in the original file, and 13 lines were modified in the new file.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 11
#       8         print(f"{old_lines} lines were modified in the original file, and {new_lines} lines were modified in the new file.")
#      10 # Count the number of added and removed lines
# ---> 11 added_lines = sum(1 for line in patch_set.added)
#      12 removed_lines = sum(1 for line in patch_set.removed)
#      14 print(f"Total added lines: {added_lines}")
#
# TypeError: 'int' object is not iterable

# %%
# Write the sampled DataFrame to a new .jsonl file
output_file_path = 'sample_output_weight.jsonl'
with open(output_file_path, 'w') as file:
    for record in df_sample.to_dict(orient='records'):
        file.write(json.dumps(record) + '\n')
