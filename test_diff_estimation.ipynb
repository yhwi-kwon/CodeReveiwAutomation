# %%
import pandas as pd
import json

# %%
# Read the .jsonl file
file_path = 'data/cls-test.jsonl'

# Load the data from jsonl
with open(file_path, 'r') as file:
    data = [json.loads(line) for line in file]

# Convert to a pandas DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#                                                    patch  y  \
# 0      @@ -87,9 +87,9 @@ public class HiveTablesTest ...  0
# 1      @@ -22,10 +22,14 @@ type LocationCache struct ...  0
# 2      @@ -0,0 +1,43 @@\n+import * as C from '../../....  1
# 3      @@ -0,0 +1,24 @@\n+// Licensed to the Software...  1
# 4      @@ -151,6 +151,27 @@ class TestCase(unittest.T...  1
# ...                                                  ... ..
# 31247  @@ -1,4 +1,4 @@\n c2.observerCardController.up...  1
# 31248  @@ -1050,7 +1050,6 @@ Lng32 ExeCliInterface::e...  0
# 31249  @@ -48,6 +48,7 @@ func (r *DefaultRuleRenderer...  0
# 31250  @@ -69,6 +69,6 @@ public final class Precondit...  1
# 31251  @@ -10005,7 +10005,7 @@ defaultdict(<class 'li...  0
#
#                                                     oldf  idx     id  \
# 0      /*\n * Copyright 2017 Netflix, Inc.\n *\n * Li...    4  13319
# 1      package manager\n\nimport (\n\t"fmt"\n\t"refle...    1  17696
# ...

# %%
df['lang'].value_counts()
# Out:
# lang
# go      9164
# java    5031
# py      4196
# cpp     3015
# js      2861
# rb      2055
# .cs     1968
# c       1777
# php     1185
# Name: count, dtype: int64

# %%
df['y'].value_counts()
# Out:
# y
# 0    15626
# 1    15626
# Name: count, dtype: int64

# %%
df_sample = df.sample(n=100, random_state=42)
df_sample['lang'].value_counts(0)
# Out:
# lang
# go      38
# java    10
# c       10
# py       9
# js       9
# rb       8
# cpp      8
# .cs      5
# php      3
# Name: count, dtype: int64

# %%
'''
go	10.262%
java 11.708%
py 16.925%
cpp 9.459%
js 9.859%
rb 4.706%
.cs 3.442%
c 4.616%
php 5.665%
'''
# Out:
# '\ngo\t10.262%\njava 11.708%\npy 16.925%\ncpp 9.459%\njs 9.859%\nrb 4.706%\n.cs 3.442%\n'

# %%
# Define the weights for sampling based on 'lang'
weights = {
    'go': 10.262,
    'java': 11.708,
    'py': 16.925,
    'cpp': 9.459,
    'js': 9.859,
    'rb': 4.706,
    '.cs': 3.442,
    'c': 4.616,
    'php': 5.665
}

weights_sum = sum(weights.values())
weights = {k: (v / weights_sum) for k, v in weights.items()}

# Map normalized weights to each row in the DataFrame
df['sampling_weight'] = df['lang'].map(weights)

# Sample 1000 rows based on normalized weights
df_sample = df.sample(n=100, weights='sampling_weight', random_state=42)
df_sample
# Out:
#                                                    patch  y  \
# 11672  @@ -1738,7 +1738,7 @@ class RandomCenterCropPa...  0
# 29716  @@ -394,6 +394,7 @@ func (app *App) createAuto...  1
# 22912  @@ -66,12 +66,12 @@ public class DefaultMailCr...  1
# 18704  @@ -661,6 +661,17 @@ public class RealTimeGetC...  0
# 4877   @@ -1428,6 +1428,23 @@ class GlobalCommands(Sc...  1
# ...                                                  ... ..
# 16300  @@ -23,7 +23,7 @@ from .util import (\n     Qu...  0
# 13336  @@ -199,7 +199,7 @@ func NewStressTestDeployme...  1
# 814    @@ -2399,12 +2399,15 @@ def ls(obj=None,  # ty...  0
# 3379   @@ -290,3 +290,29 @@ type NetworkPolicyNodeSta...  1
# 1000   @@ -243,7 +243,9 @@ func TestBatchContainerHap...  1
#
#                                                     oldf  idx     id  \
# 11672  import copy\nimport inspect\n\nimport mmcv\nim...   20  24834
# 29716  package caddyhttp\n\nimport (\n\t"fmt"\n\t"net...    1  14351
# ...

# %%
df_sample['lang'].value_counts()
# Out:
# lang
# go      35
# py      22
# java    20
# cpp      9
# js       5
# rb       4
# c        2
# .cs      2
# php      1
# Name: count, dtype: int64

# %%
# Write the sampled DataFrame to a new .jsonl file
output_file_path = 'sample_output.jsonl'
with open(output_file_path, 'w') as file:
    for record in df_sample.to_dict(orient='records'):
        file.write(json.dumps(record) + '\n')
